# %% [markdown]
# # Python Data Science Toolbox (Part 1)
#
# 👋 Welcome to your workspace! Here, you can write and run Python code and add text in [Markdown](https://www.markdownguide.org/basic-syntax/). Below, we've imported the datasets from the course _Python Data Science Toolbox (Part 1)_ as DataFrames as well as the packages used in the course. This is your sandbox environment: analyze the course datasets further, take notes, or experiment with code!

# %%
# Importing course packages; you can add more too!
import pandas as pd
from functools import reduce

# Importing course datasets as DataFrames
tweets = pd.read_csv('datasets/tweets.csv')

tweets.head() # Display the first five rows
# Out:
#    contributors  coordinates                      created_at  \
# 0           NaN          NaN  Tue Mar 29 23:40:17 +0000 2016
# 1           NaN          NaN  Tue Mar 29 23:40:17 +0000 2016
# 2           NaN          NaN  Tue Mar 29 23:40:17 +0000 2016
# 3           NaN          NaN  Tue Mar 29 23:40:17 +0000 2016
# 4           NaN          NaN  Tue Mar 29 23:40:17 +0000 2016
#
#                                             entities  \
# 0  {'hashtags': [], 'user_mentions': [{'screen_na...
# 1  {'hashtags': [{'text': 'cruzsexscandal', 'indi...
# 2  {'hashtags': [], 'user_mentions': [], 'symbols...
# 3  {'hashtags': [], 'user_mentions': [], 'symbols...
# 4  {'hashtags': [], 'user_mentions': [{'screen_na...
#
#                                    extended_entities  favorite_count  \
# 0  {'media': [{'sizes': {'large': {'w': 1024, 'h'...               0
# 1  {'media': [{'sizes': {'large': {'w': 500, 'h':...               0
# ...

# %%
# Begin writing your own code here!
tweets.describe()
#tweets.shape
#tweets.value_counts()
tweets.nunique(axis = 0)
tweets[tweets.duplicated('id', keep=False) == True].sort_values(by = 'id')

tweets.query('id == 714960402229116928')
tweets[tweets['favorite_count'] > 0]
#tweets.describe()
# Out:
# Empty DataFrame
# Columns: [contributors, coordinates, created_at, entities, extended_entities, favorite_count, favorited, filter_level, geo, id, id_str, in_reply_to_screen_name, in_reply_to_status_id, in_reply_to_status_id_str, in_reply_to_user_id, in_reply_to_user_id_str, is_quote_status, lang, place, possibly_sensitive, quoted_status, quoted_status_id, quoted_status_id_str, retweet_count, retweeted, retweeted_status, source, text, timestamp_ms, truncated, user]
# Index: []
#
# [0 rows x 31 columns]

# %% [markdown]
# ### Write a function that takes a timestamp (see column timestamp_ms) and returns the text of any tweet published at that timestamp. Additionally, make it so that users can pass column names as flexible arguments (*args) so that the function can print out any other columns users want to see.

# %%
def show_text(timestamp, *args):
    try:
        column_list = []
        if args == (): 
            args = (['text'])   # to dafult to atleast one column as text
        column_list1 = [column for column in args]
        #print(column_list1)
        #return timestamp_ms
        #print(tweets.query("timestamp_ms == @timestamp")[column_list1])
        #print(tweets[tweets['timestamp_ms'] == timestamp][column_list1])
        return tweets.query("timestamp_ms == @timestamp")[column_list1]
    except KeyError as e:
        print(e)
    

time_ms = show_text(1459294817758, 'text', 'id' )
time_ms
# Out:
#                                                 text                  id
# 0  RT @bpolitics: .@krollbondrating's Christopher...  714960401759387648
# 5  RT @BIackPplTweets: Young Donald trump meets h...  714960401759412224

# %% [markdown]
# ### In a filter() call, write a lambda function to return tweets created on a Tuesday. Tip: look at the first three characters of the created_at column.

# %%
df_list = list(filter(lambda x:x.startswith('Tue Mar 29 23:40:19'), tweets['created_at']))

tweets.loc[tweets['created_at'].isin(df_list)]
# Out:
#     contributors  coordinates                      created_at  \
# 60           NaN          NaN  Tue Mar 29 23:40:19 +0000 2016
# 64           NaN          NaN  Tue Mar 29 23:40:19 +0000 2016
# 65           NaN          NaN  Tue Mar 29 23:40:19 +0000 2016
# 66           NaN          NaN  Tue Mar 29 23:40:19 +0000 2016
# 68           NaN          NaN  Tue Mar 29 23:40:19 +0000 2016
# 69           NaN          NaN  Tue Mar 29 23:40:19 +0000 2016
# 70           NaN          NaN  Tue Mar 29 23:40:19 +0000 2016
# 72           NaN          NaN  Tue Mar 29 23:40:19 +0000 2016
# 73           NaN          NaN  Tue Mar 29 23:40:19 +0000 2016
# 74           NaN          NaN  Tue Mar 29 23:40:19 +0000 2016
# 76           NaN          NaN  Tue Mar 29 23:40:19 +0000 2016
# 77           NaN          NaN  Tue Mar 29 23:40:19 +0000 2016
# 78           NaN          NaN  Tue Mar 29 23:40:19 +0000 2016
# 79           NaN          NaN  Tue Mar 29 23:40:19 +0000 2016
# ...

# %% [markdown]
# ### In a filter() call, write a lambda function to return tweets created on a Tuesday. Tip: look at the first three characters of the created_at column.

# %%
tweets.loc[tweets['created_at'].isin(filter(lambda x:x.startswith('Tue Mar 29 23:40:17'), tweets['created_at']))]

#tweets.loc[tweets['created_at'].isin(df_list)]
# Out:
#     contributors  coordinates                      created_at  \
# 0            NaN          NaN  Tue Mar 29 23:40:17 +0000 2016
# 1            NaN          NaN  Tue Mar 29 23:40:17 +0000 2016
# 2            NaN          NaN  Tue Mar 29 23:40:17 +0000 2016
# 3            NaN          NaN  Tue Mar 29 23:40:17 +0000 2016
# 4            NaN          NaN  Tue Mar 29 23:40:17 +0000 2016
# 5            NaN          NaN  Tue Mar 29 23:40:17 +0000 2016
# 7            NaN          NaN  Tue Mar 29 23:40:17 +0000 2016
# 11           NaN          NaN  Tue Mar 29 23:40:17 +0000 2016
# 14           NaN          NaN  Tue Mar 29 23:40:17 +0000 2016
# 17           NaN          NaN  Tue Mar 29 23:40:17 +0000 2016
# 19           NaN          NaN  Tue Mar 29 23:40:17 +0000 2016
# 24           NaN          NaN  Tue Mar 29 23:40:17 +0000 2016
# 27           NaN          NaN  Tue Mar 29 23:40:17 +0000 2016
#
#                                              entities  \
# ...

# %% [markdown]
# ### Don't know where to start?
#
# Try completing these tasks:
# - Write a function that takes in `tweets` and returns two values: the average amount of times tweets in `tweets` have been favorited and retweeted.
# - Write a function that takes a timestamp (see column `timestamp_ms`) and returns the text of any tweet published at that timestamp. Additionally, make it so that users can pass column names as flexible arguments (`*args`) so that the function can print out any other columns users want to see.
# - In a `filter()` call, write a lambda function to return tweets created on a Tuesday. Tip: look at the first three characters of the `created_at` column.
# - Make sure to add error handling on the functions you've created!
